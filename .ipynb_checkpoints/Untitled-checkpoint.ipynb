# %%
import pandas as pd
df = pd.read_csv('csv1.csv')
print(df.head)
# Out:
# <bound method DataFrame.head of                                           Gene Transcription factor  \
# 0    AT1G15780|5436212-5437912|Chr1|(strand=-)                ARF16
# 1    AT1G15780|5436212-5437912|Chr1|(strand=-)                 ARR1
# 2    AT1G15780|5436212-5437912|Chr1|(strand=-)                ARR10
# 3    AT1G15780|5436212-5437912|Chr1|(strand=-)                ASR-1
# 4    AT1G15780|5436212-5437912|Chr1|(strand=-)            AT1G77200
# 5    AT1G15780|5436212-5437912|Chr1|(strand=-)            At3g20750
# 6    AT1G15780|5436212-5437912|Chr1|(strand=-)            AT3G25990
# 7    AT1G15780|5436212-5437912|Chr1|(strand=-)            At3g51080
# 8    AT1G15780|5436212-5437912|Chr1|(strand=-)            AT4G12670
# 9    AT1G15780|5436212-5437912|Chr1|(strand=-)               ATHB-6
# 10   AT1G15780|5436212-5437912|Chr1|(strand=-)             ATHSFA1D
# 11   AT1G15780|5436212-5437912|Chr1|(strand=-)               bHLH64
# 12   AT1G15780|5436212-5437912|Chr1|(strand=-)                 BPC1
# 13   AT1G15780|5436212-5437912|Chr1|(strand=-)               CAMTA1
# 14   AT1G15780|5436212-5437912|Chr1|(strand=-)                 CBF3
# 15   AT1G15780|5436212-5437912|Chr1|(strand=-)                CBNAC
# 16   AT1G15780|5436212-5437912|Chr1|(strand=-)                 CDF3
# 17   AT1G15780|5436212-5437912|Chr1|(strand=-)                 DEL1
# 18   AT1G15780|5436212-5437912|Chr1|(strand=-)                 DEL2
# 19   AT1G15780|5436212-5437912|Chr1|(strand=-)               DOF4.3
# 20   AT1G15780|5436212-5437912|Chr1|(strand=-)                 EDT1
# 21   AT1G15780|5436212-5437912|Chr1|(strand=-)                 GT-1
# 22   AT1G15780|5436212-5437912|Chr1|(strand=-)                HMG-1
# 23   AT1G15780|5436212-5437912|Chr1|(strand=-)                HSFA2
# 24   AT1G15780|5436212-5437912|Chr1|(strand=-)               HSFA4A
# 25   AT1G15780|5436212-5437912|Chr1|(strand=-)               MYB118
# 26   AT1G15780|5436212-5437912|Chr1|(strand=-)               Myb-15
# 27   AT1G15780|5436212-5437912|Chr1|(strand=-)            MYB1-like
# 28   AT1G15780|5436212-5437912|Chr1|(strand=-)                MYB24
# 29   AT1G15780|5436212-5437912|Chr1|(strand=-)               MYB3R1
# ..                                         ...                  ...
# 666                                  At4g35740               HSFA4A
# 667                                  At4g35740                  HY5
# 668                                  At4g35740                 LBD2
# 669                                  At4g35740               Myb-15
# 670                                  At4g35740            MYB1-like
# 671                                  At4g35740                MYB24
# 672                                  At4g35740               MYB3R1
# 673                                  At4g35740               MYB3R4
# 674                                  At4g35740               MYB3R5
# 675                                  At4g35740               NAC078
# 676                                  At4g35740              OCSBF-1
# 677                                  At4g35740             Opaque-2
# 678                                  At4g35740                  PBF
# 679                                  At4g35740                 PIF3
# 680                                  At4g35740               RAP2-6
# 681                                  At4g35740               RAP2.1
# 682                                  At4g35740               RAP2.6
# 683                                  At4g35740                RRTF1
# 684                                  At4g35740                SPL15
# 685                                  At4g35740                 SPL3
# 686                                  At4g35740                 SPL5
# 687                                  At4g35740                 TGA2
# 688                                  At4g35740                 TGA5
# 689                                  At4g35740                 TGA6
# 690                                  At4g35740                 TGA7
# 691                                  At4g35740                 WRKY
# 692                                  At4g35740               WRKY43
# 693                                  At4g35740               WRKY57
# 694                                  At4g35740                WRKY6
# 695                                        NaN                  NaN
#
#      Frequency       Family  Unnamed: 4
# 0          4.0          ARF         NaN
# 1          1.0        ARR-B         NaN
# 2          1.0        ARR-B         NaN
# 3          3.0          MYB         NaN
# 4          1.0          ERF         NaN
# 5          1.0    C2C2-Gata         NaN
# 6          3.0     Trihelix         NaN
# 7          1.0    C2C2-Gata         NaN
# 8          1.0     Homeobox         NaN
# 9          2.0     Homeobox         NaN
# 10         1.0          HSF         NaN
# 11         1.0         bHLH         NaN
# 12         1.0          BPC         NaN
# 13         1.0        CAMTA         NaN
# 14         1.0          ERF         NaN
# 15         3.0          NAC         NaN
# 16         1.0     C2C2-Dof         NaN
# 17         4.0       E2F-DP         NaN
# 18         2.0       E2F-DP         NaN
# 19         2.0     C2C2-Dof         NaN
# 20         1.0       Others         NaN
# 21         3.0     Trihelix         NaN
# 22         1.0       Others         NaN
# 23         2.0          HSF         NaN
# 24         2.0          HSF         NaN
# 25         2.0          MYB         NaN
# 26         5.0  MYB related         NaN
# 27         1.0          MYB         NaN
# 28         2.0          MYB         NaN
# 29         9.0          MYB         NaN
# ..         ...          ...         ...
# 666        1.0          HSF         NaN
# 667        1.0         bZIP         NaN
# 668       11.0       Others         NaN
# 669        4.0          MYB         NaN
# 670        1.0          MYB         NaN
# 671        2.0          MYB         NaN
# 672        8.0          MYB         NaN
# 673        7.0          MYB         NaN
# 674        7.0          MYB         NaN
# 675        1.0          NAC         NaN
# 676        2.0       others         NaN
# 677        3.0         bZIP         NaN
# 678        2.0       Others         NaN
# 679        2.0         bHLH         NaN
# 680        1.0          ERF         NaN
# 681        1.0          ERF         NaN
# 682        1.0          ERF         NaN
# 683        1.0      AP2/ERF         NaN
# 684        1.0          SBP         NaN
# 685        1.0          SBP         NaN
# 686        1.0          SBP         NaN
# 687        2.0         bZIP         NaN
# 688        2.0         bZIP         NaN
# 689        1.0         bZIP         NaN
# 690        1.0         bZIP         NaN
# 691        1.0         WRKY         NaN
# 692        1.0         WRKY         NaN
# 693        1.0         WRKY         NaN
# 694        1.0         WRKY         NaN
# 695        NaN          NaN         NaN
#
# [696 rows x 5 columns]>

# %%
df['Family'].to_csv('new.csv')

# %%
ls
# Out:
# Book1_new.xlsx  Untitled.ipynb  csv1.csv        new.csv         regression.py

# %%
head new.csv
# Out:
#   File "<ipython-input-4-102a1f29e7e5>", line 1
#     head new.csv
#            ^
# SyntaxError: invalid syntax

# %%
df= pd.read_csv('csv1.csv', index_col=0)

# %%
print(df.head())
# Out:
#                                           Transcription factor  Frequency  \
# Gene
# AT1G15780|5436212-5437912|Chr1|(strand=-)                ARF16        4.0
# AT1G15780|5436212-5437912|Chr1|(strand=-)                 ARR1        1.0
# AT1G15780|5436212-5437912|Chr1|(strand=-)                ARR10        1.0
# AT1G15780|5436212-5437912|Chr1|(strand=-)                ASR-1        3.0
# AT1G15780|5436212-5437912|Chr1|(strand=-)            AT1G77200        1.0
#
#                                           Family  Unnamed: 4
# Gene
# AT1G15780|5436212-5437912|Chr1|(strand=-)    ARF         NaN
# AT1G15780|5436212-5437912|Chr1|(strand=-)  ARR-B         NaN
# AT1G15780|5436212-5437912|Chr1|(strand=-)  ARR-B         NaN
# AT1G15780|5436212-5437912|Chr1|(strand=-)    MYB         NaN
# AT1G15780|5436212-5437912|Chr1|(strand=-)    ERF         NaN

# %%
df.to_html('example.html')

# %% [markdown]
# jjk

# %%
nj
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-ada0511d484a> in <module>()
# ----> 1 nj
#
# NameError: name 'nj' is not defined

# %%
fiddy_states = pd.read_html('https://simple.wikipedia.org/wiki/List_of_U.S._states')

# %%
print(fiddy_states[0][2][-3:])
# Out:
# 48    West Virginia
# 49        Wisconsin
# 50          Wyoming
# Name: 2, dtype: object

# %%
print(fiddy_states[0][1][3:])
# Out:
# 3     AZ
# 4     AR
# 5     CA
# 6     CO
# 7     CT
# 8     DE
# 9     FL
# 10    GA
# 11    HI
# 12    ID
# 13    IL
# 14    IN
# 15    IA
# 16    KS
# 17    KY
# 18    LA
# 19    ME
# 20    MD
# 21    MA
# 22    MI
# 23    MN
# 24    MS
# 25    MO
# 26    MT
# 27    NE
# 28    NV
# 29    NH
# 30    NJ
# 31    NM
# 32    NY
# 33    NC
# 34    ND
# 35    OH
# 36    OK
# 37    OR
# 38    PA
# 39    RI
# 40    SC
# 41    SD
# 42    TN
# 43    TX
# 44    UT
# 45    VT
# 46    VA
# 47    WA
# 48    WV
# 49    WI
# 50    WY
# Name: 1, dtype: object

# %%
for abv in fiddy_states[0][1][1:]:
    print('hey ' +abv)
# Out:
# hey AL
# hey AK
# hey AZ
# hey AR
# hey CA
# hey CO
# hey CT
# hey DE
# hey FL
# hey GA
# hey HI
# hey ID
# hey IL
# hey IN
# hey IA
# hey KS
# hey KY
# hey LA
# hey ME
# hey MD
# hey MA
# hey MI
# hey MN
# hey MS
# hey MO
# hey MT
# hey NE
# hey NV
# hey NH
# hey NJ
# hey NM
# hey NY
# hey NC
# hey ND
# hey OH
# hey OK
# hey OR
# hey PA
# hey RI
# hey SC
# hey SD
# hey TN
# hey TX
# hey UT
# hey VT
# hey VA
# hey WA
# hey WV
# hey WI
# hey WY

# %%
df1 = pd.DataFrame({'HPI':[80,85,88,85],
                    'Int_rate':[2, 3, 2, 2],
                    'US_GDP_Thousands':[50, 55, 65, 55]},
                   index = [2001, 2002, 2003, 2004])

df2 = pd.DataFrame({'HPI':[80,85,88,85],
                    'Int_rate':[2, 3, 2, 2],
                    'US_GDP_Thousands':[50, 55, 65, 55]},
                   index = [2005, 2006, 2007, 2008])

df3 = pd.DataFrame({'HPI':[80,85,88,85],
                    'Int_rate':[2, 3, 2, 2],
                    'Low_tier_HPI':[50, 52, 50, 53]},
                   index = [2001, 2002, 2003, 2004])

# %%
print (pd.concat([df1,df2]))
# Out:
#       HPI  Int_rate  US_GDP_Thousands
# 2001   80         2                50
# 2002   85         3                55
# 2003   88         2                65
# 2004   85         2                55
# 2005   80         2                50
# 2006   85         3                55
# 2007   88         2                65
# 2008   85         2                55

# %%
print(df1.append([df2]))
# Out:
#       HPI  Int_rate  US_GDP_Thousands
# 2001   80         2                50
# 2002   85         3                55
# 2003   88         2                65
# 2004   85         2                55
# 2005   80         2                50
# 2006   85         3                55
# 2007   88         2                65
# 2008   85         2                55

# %%
s = pd.Series([80,2,50], index=['HPI','Int_rate','US_GDP_Thousands'])
print s
# Out:
# HPI                 80
# Int_rate             2
# US_GDP_Thousands    50
# dtype: int64

# %%
print(pd.merge(df1,df2))
# Out:
#    HPI  Int_rate  US_GDP_Thousands
# 0   80         2                50
# 1   85         3                55
# 2   88         2                65
# 3   85         2                55

# %%
print(pd.merge(df2,df3))
# Out:
#    HPI  Int_rate  US_GDP_Thousands  Low_tier_HPI
# 0   80         2                50            50
# 1   85         3                55            52
# 2   88         2                65            50
# 3   85         2                55            53

# %%
import quandl
import pandas as pd

# Not necessary, I just do this so I do not show my API key.
api_key = open('quandlapikey.txt','r').read()
fiddy_states = pd.read_html('https://simple.wikipedia.org/wiki/List_of_U.S._states')

main_df = pd.DataFrame()

for abbv in fiddy_states[0][0][1:]:
    query = "FMAC/HPI_"+str(abbv)
    df = quandl.get(query, authtoken=api_key)

    if main_df.empty:
        main_df = df
    else:
        main_df = main_df.join(df)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-0ae9ed17b931> in <module>()
#       3
#       4 # Not necessary, I just do this so I do not show my API key.
# ----> 5 api_key = open('quandlapikey.txt','r').read()
#       6 fiddy_states = pd.read_html('https://simple.wikipedia.org/wiki/List_of_U.S._states')
#       7
#
# IOError: [Errno 2] No such file or directory: 'quandlapikey.txt'

# %%
import pandas as pd
import quandl

df = quandl.get("WIKI/GOOGL")

print(df.head())
# Out:
#               Open    High     Low    Close      Volume  Ex-Dividend  \
# Date
# 2004-08-19  100.01  104.06   95.96  100.335  44659000.0          0.0
# 2004-08-20  101.01  109.08  100.50  108.310  22834300.0          0.0
# 2004-08-23  110.76  113.48  109.05  109.400  18256100.0          0.0
# 2004-08-24  111.24  111.60  103.57  104.870  15247300.0          0.0
# 2004-08-25  104.76  108.00  103.88  106.000   9188600.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2004-08-19          1.0  50.159839  52.191109  48.128568   50.322842
# 2004-08-20          1.0  50.661387  54.708881  50.405597   54.322689
# 2004-08-23          1.0  55.551482  56.915693  54.693835   54.869377
# 2004-08-24          1.0  55.792225  55.972783  51.945350   52.597363
# 2004-08-25          1.0  52.542193  54.167209  52.100830   53.164113
#
#             Adj. Volume
# Date
# 2004-08-19   44659000.0
# 2004-08-20   22834300.0
# 2004-08-23   18256100.0
# 2004-08-24   15247300.0
# 2004-08-25    9188600.0

# %%
df = df[['Adj. Open',  'Adj. High',  'Adj. Low',  'Adj. Close', 'Adj. Volume']]

# %%
df['HL_PCT'] = (df['Adj. High'] - df['Adj. Low']) / df['Adj. Close'] * 100.0

# %%
df['PCT_change'] = (df['Adj. Close'] - df['Adj. Open']) / df['Adj. Open'] * 100.0

# %%
df = df[['Adj. Close', 'HL_PCT', 'PCT_change', 'Adj. Volume']]
print(df.head())
# Out:
#             Adj. Close    HL_PCT  PCT_change  Adj. Vol
#  ...
#  [ 3.12606095 -0.42033784  0.33294124 -0.61680539]
#  [ 2.87589111 -0.22857327 -0.47201183 -0.25114711]
#  [ 2.67363808  2.38804314 -1.91773798 -0.4998129 ]]

# %%
print forecast_out
# Out:
# 35

# %%
print X_train
# Out:
# [[-0.79266921  1.14395051  0.75761407 -0.01855079]
#  [-0.65681972 -0.35098073 -0.79092665 -0.03292845]
#  [ 2.40430151 -0.93789046  0.20012802 -0.78933347]
#  ...
#  [ 2.2320015  -0.67645502  0.06441615 -0.65187925]
#  [-1.01714768 -0.12405116  0.86344903  0.85820788]
#  [-0.39059091 -0.63239099  0.68809609 -0.56302729]]

# %%
print y_train
# Out:
# [212.72666684 279.47772095 952.51       ... 945.75       140.22285452
#  283.48007584]

# %%
y = np.array(df['label'])

# %%
X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y, test_size=0.2)

# %%
print y_train
# Out:
# [253.25677942 165.54100924 450.40485664 ... 805.96       453.94628871
#  230.91782119]

# %%
clf = svm.SVR()

# %%
clf.fit(X_train, y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
confidence = clf.score(X_test, y_test)

# %%
print confidence
# Out:
# 0.7699338654000143

# %%
clf = LinearRegression()

# %%
clf.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
confidence = clf.score(X_test, y_test)

# %%
print confidence
# Out:
# 0.9775830067199751

# %%
for k in ['linear','poly','rbf','sigmoid']:
    clf = svm.SVR(kernel=k)
    clf.fit(X_train, y_train)
    confidence = clf.score(X_test, y_test)
    print(k,confidence)
# Out:
# ('linear', 0.9767956433102553)
# ('poly', 0.6424934789140477)
# ('rbf', 0.7699338654000143)
# ('sigmoid', 0.8863404623669129)

# %%
print forecast_set
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-2d30772d0f19> in <module>()
# ----> 1 print forecast_set
#
# NameError: name 'forecast_set' is not defined

# %%
print X_lately
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-b9b5bcc6512b> in <module>()
# ----> 1 print X_lately
#
# NameError: name 'X_lately' is not defined

# %%
forecast_set = clf.predict(X_lately)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-61e34dcc41bc> in <module>()
# ----> 1 forecast_set = clf.predict(X_lately)
#
# NameError: name 'X_lately' is not defined

# %%
X_lately = X[-forecast_out:]

# %%
print X_lately
# Out:
# [[ 2.62836772 -0.60395442  0.14019752 -0.76716771]
#  [ 2.68662975 -0.50403838  0.53097279 -0.57983089]
#  [ 2.7391177  -0.45286742  0.55095625 -0.77306097]
#  [ 2.7178258  -0.67458944 -0.18488046 -0.79662122]
#  [ 2.692885   -0.67437869 -0.43982364 -0.77955849]
#  [ 2.68201851 -0.94726629 -0.26703183 -0.80592231]
#  [ 2.67403906 -1.24386097 -0.05623854 -0.84827073]
#  [ 2.66196963 -0.83030254 -0.15944615 -0.84176825]
#  [ 2.63931441 -0.84894476 -0.38581877 -0.82809679]
#  [ 2.62227286 -0.73971534 -0.38117269 -0.83358049]
#  [ 2.61204794 -1.15345677 -0.11732681 -0.81253132]
#  [ 2.69148158  0.01560903  1.29540984 -0.76422869]
#  [ 2.76490055 -0.02914446  1.10879082 -0.76485942]
#  [ 2.78190199 -0.87521473 -0.06604773 -0.7964564 ]
#  [ 2.84016402 -0.75712388  0.42889739 -0.77177666]
#  [ 2.85588234 -0.92829357  0.20787616 -0.81342602]
#  [ 2.85018846 -0.85799728 -0.32246025 -0.79080909]
#  [ 2.83956255 -0.94937071  0.20435033 -0.82807901]
#  [ 2.84653956 -0.9779713  -0.01090247 -0.81904854]
#  [ 2.92180303 -0.04135693  1.25122636 -0.72085981]
#  [ 2.92200352 -0.10923147 -0.54791615 -0.73664972]
#  [ 2.95568563 -0.5215837   0.17594757 -0.78874108]
#  [ 2.94313503 -0.49991618 -0.18320879 -0.79109471]
#  [ 2.97332864 -0.81053552  0.33592027 -0.7808474 ]
#  [ 3.05617058  0.02510259  1.20251833 -0.77847998]
#  [ 3.10432798 -0.83138779  0.33154758 -0.73081583]
#  [ 3.08476028 -0.3152546  -0.75664586 -0.73250196]
#  [ 3.12826633 -0.71968271  0.09580094 -0.7831951 ]
#  [ 3.14999931 -0.33896485  0.01660257 -0.71275609]
#  [ 3.14566875 -0.67549345 -0.07053322 -0.76687423]
#  [ 3.10913971 -0.70062702 -0.004932   -0.73559515]
#  [ 3.12858711 -0.6554886  -0.07478472 -0.75357931]
#  [ 3.12606095 -0.42033784  0.33294124 -0.61680539]
#  [ 2.87589111 -0.22857327 -0.47201183 -0.25114711]
#  [ 2.67363808  2.38804314 -1.91773798 -0.4998129 ]]

# %%
import quandl, math
import numpy as np
import pandas as pd
from sklearn import preprocessing, cross_validation, svm
# %matplotlib notebook
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from matplotlib import style
import datetime

style.use('ggplot')

df = quandl.get("WIKI/GOOGL")
df = df[['Adj. Open',  'Adj. High',  'Adj. Low',  'Adj. Close', 'Adj. Volume']]
df['HL_PCT'] = (df['Adj. High'] - df['Adj. Low']) / df['Adj. Close'] * 100.0
df['PCT_change'] = (df['Adj. Close'] - df['Adj. Open']) / df['Adj. Open'] * 100.0

df = df[['Adj. Close', 'HL_PCT', 'PCT_change', 'Adj. Volume']]
forecast_col = 'Adj. Close'
df.fillna(value=-99999, inplace=True)
forecast_out = int(math.ceil(0.01 * len(df)))
df['label'] = df[forecast_col].shift(-forecast_out)

X = np.array(df.drop(['label'], 1))
X = preprocessing.scale(X)
X_lately = X[-forecast_out:]
X = X[:-forecast_out]

df.dropna(inplace=True)

y = np.array(df['label'])

X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y, test_size=0.2)
clf = LinearRegression(n_jobs=-1)
clf.fit(X_train, y_train)
confidence = clf.score(X_test, y_test)

forecast_set = clf.predict(X_lately)
df['Forecast'] = np.nan

last_date = df.iloc[-1].name
last_unix = last_date.timestamp()
one_day = 86400
next_unix = last_unix + one_day

for i in forecast_set:
    next_date = datetime.datetime.fromtimestamp(next_unix)
    next_unix += 86400
    df.loc[next_date] = [np.nan for _ in range(len(df.columns)-1)]+[i]

df['Adj. Close'].plot()
df['Forecast'].plot()
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(forecast_set, confidence, forecast_out)
# Out:
# (array([1103.12293702, 1076.70335333, 1025.25854724, 1062.05054647,
#        1075.78683835, 1075.88061469, 1093.77082249, 1112.90300847,
#        1117.59018221, 1125.32025367, 1135.51238131, 1132.41467408,
#        1150.54682849, 1166.47816664, 1139.89606896, 1126.00235735,
#        1092.46600081, 1104.58705063, 1116.21442926, 1123.61226189,
#        1136.74937805, 1151.98257601, 1183.01287748, 1188.82618731,
#        1162.01298026, 1171.61717211, 1173.13627578, 1156.84766235,
#        1121.64578508, 1117.47706696, 1115.87342044, 1073.98705773,
#        1046.95241489, 1073.77577529, 1026.32495103]), 0.977928899793554, 35)

# %%
print confidence
# Out:
# 0.977928899793554

# %%
forecast_set = clf.predict(X_lately
# Out:
#   File "<ipython-input-59-f1cc51529c96>", line 1
#     forecast_set = clf.predict(X_lately
#                                        ^
# SyntaxError: unexpected EOF while parsing

# %%
forecast_set = clf.predict(X_lately)

# %%
print labels
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-ae4f7e66bb1d> in <module>()
# ----> 1 print labels
#
# NameError: name 'labels' is not defined

# %%
from statistics import mean
import numpy as np

# %%
xs=[1,2,3,4,5]

# %%
ys=[5,4,6,5,6]

# %%
xs = np.array([1,2,3,4,5], dtype=np.float64)
ys = np.array([5,4,6,5,6], dtype=np.float64)

# %%
print xs
# Out:
# [1. 2. 3. 4. 5.]

# %%
xs=[1,2,3,4,5]

# %%
print xs
# Out:
# [1, 2, 3, 4, 5]

# %%
x = np.array([1,2,3,4,5], dtype=np.float64)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(xs)

# %%
plt.show()

# %%
print x
# Out:
# [1. 2. 3. 4. 5.]

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from '/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc'>

# %%
plt.plot(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-7bb472d004ec> in <module>()
# ----> 1 plt.plot[x]
#
# TypeError: 'function' object has no attribute '__getitem__'

# %%
xs = np.array([1,2,3,4,5], dtype=np.float64)
ys = np.array([5,4,6,5,6], dtype=np.float64)

# %%
plt.plot(xs,ys)

# %%
plt.show()

# %%
import quandl, math
import numpy as np
import pandas as pd
from sklearn import preprocessing, cross_validation, svm
# %matplotlib notebook
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from matplotlib import style
import datetime

style.use('ggplot')

df = quandl.get("WIKI/GOOGL")
df = df[['Adj. Open',  'Adj. High',  'Adj. Low',  'Adj. Close', 'Adj. Volume']]
df['HL_PCT'] = (df['Adj. High'] - df['Adj. Low']) / df['Adj. Close'] * 100.0
df['PCT_change'] = (df['Adj. Close'] - df['Adj. Open']) / df['Adj. Open'] * 100.0

df = df[['Adj. Close', 'HL_PCT', 'PCT_change', 'Adj. Volume']]
forecast_col = 'Adj. Close'
df.fillna(value=-99999, inplace=True)
forecast_out = int(math.ceil(0.01 * len(df)))
df['label'] = df[forecast_col].shift(-forecast_out)

X = np.array(df.drop(['label'], 1))
X = preprocessing.scale(X)
X_lately = X[-forecast_out:]
X = X[:-forecast_out]

df.dropna(inplace=True)

y = np.array(df['label'])

X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y, test_size=0.2)
clf = LinearRegression(n_jobs=-1)
clf.fit(X_train, y_train)
confidence = clf.score(X_test, y_test)

forecast_set = clf.predict(X_lately)
df['Forecast'] = np.nan

last_date = df.iloc[-1].name
last_unix = last_date.timestamp()
one_day = 86400
next_unix = last_unix + one_day

for i in forecast_set:
    next_date = datetime.datetime.fromtimestamp(next_unix)
    next_unix += 86400
    df.loc[next_date] = [np.nan for _ in range(len(df.columns)-1)]+[i]

df['Adj. Close'].plot()
df['Forecast'].plot()
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-89-8341ae88ea6a> in <module>()
# ----> 1 x.plot()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline

# %%
xs = np.array([1,2,3,4,5], dtype=np.float64)
ys = np.array([5,4,6,5,6], dtype=np.float64)

# %%
plt.plot(xs, ys)

# %%
from statistics import mean
import numpy as np

xs = np.array([1,2,3,4,5], dtype=np.float64)
ys = np.array([5,4,6,5,6], dtype=np.float64)

def best_fit_slope(xs,ys):
    m = (((mean(xs)*mean(ys)) - mean(xs*ys)) /
         ((mean(xs)**2) - mean(xs**2)))
    return m

a = best_fit_slope(xs,ys)
print(a)
# Out:
# 0.29999999999999893
